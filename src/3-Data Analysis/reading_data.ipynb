# %%
import pandas as pd

# %%
url ="https://www.fdic.gov/bank-failures/failed-bank-list"

df = pd.read_html(url)

# %%
df[0]
# Out:
#                                Bank Name               City          State  \
# 0  Republic First Bank dba Republic Bank       Philadelphia   Pennsylvania
# 1                          Citizens Bank           Sac City           Iowa
# 2               Heartland Tri-State Bank            Elkhart         Kansas
# 3                    First Republic Bank      San Francisco     California
# 4                         Signature Bank           New York       New York
# 5                    Silicon Valley Bank        Santa Clara     California
# 6                      Almena State Bank             Almena         Kansas
# 7             First City Bank of Florida  Fort Walton Beach        Florida
# 8                   The First State Bank      Barboursville  West Virginia
# 9                     Ericson State Bank            Ericson       Nebraska
#
#     Cert                 Aquiring Institution       Closing Date   Fund
# 0  27332    Fulton Bank, National Association     April 26, 2024  10546
# ...

# %%
# !pip install html5lib
# !pip install beautifulsoup4

# %%
url = 'https://en.wikipedia.org/wiki/Mobile_network_codes_in_ITU_region_2xx_(Europe)'
df = pd.read_html(url,match='Brand',header=0)[1]

# %%
## Pickle file - serialized data

## Saving it to pickle file
df.to_pickle('df_pickle')

##Reading pickle file
df_pickle = pd.read_pickle('df_pickle')
df_pickle.head()
# Out:
#    MCC  MNC               Brand            Operator           Status  \
# 0  276    1                 ONE         One Albania      Operational
# 1  276    2            Vodafone    Vodafone Albania      Operational
# 2  276    3          ALBtelecom          Albtelecom  Not operational
# 3  276    4  Plus Communication  Plus Communication  Not operational
#
#                                          Bands (MHz)  \
# 0  GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800 / LT...
# 1  GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800 / LT...
# 2          GSM 900 / GSM 1800 / UMTS 2100 / LTE 1800
# 3                     GSM 900 / GSM 1800 / UMTS 2100
#
#                                 References and notes
# 0  Former One Telecommunications, Telekom Albania...
# 1                                                [2]
# 2  Former Eagle Mobile;[2][3] merged with ONE in ...
# 3        [4] Shut down Jan 2018;[5] MNC withdrawn[3]
